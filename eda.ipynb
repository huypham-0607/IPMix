# %%
import pandas as pd

df = pd.read_csv('result/calibration_summary.csv')

print(df)
# Out:
#     dataset       model  n_samples  accuracy_pct  rms_calib_error_pct
# 0   cifar10    wrn28-10      10000         96.65                 1.95
# 1   cifar10     wrn40-4      10000         96.00                 2.33
# 2   cifar10  resnext-29      10000         96.15                 2.06
# 3   cifar10   resnet-18      10000         95.77                 2.48
# 4   cifar10   resnet-20      10000         91.94                 3.63
# 5  cifar100    wrn28-10      10000         82.58                 6.50
# 6  cifar100     wrn40-4      10000         80.59                 2.95
# 7  cifar100  resnext-29      10000         81.67                 3.72
# 8  cifar100   resnet-18      10000         78.34                 6.18
# 9  cifar100   resnet-20      10000         69.12                 5.92

# %%
df = pd.read_csv('result/ipmix_results.csv')

print(df)
# Out:
#         model   dataset  clean_error_orig  clean_error_repro  mce_orig  \
# 0     wrn40-4   cifar10               4.0               4.00       8.6
# 1    wrn28-10   cifar10               3.3               3.30       7.5
# 2  resnext-29   cifar10               3.8               3.80       8.6
# 3   resnet-18   cifar10               4.2               4.20       8.4
# 4   resnet-20   cifar10               NaN               8.06       NaN
# 5     wrn40-4  cifar100              19.4              19.40      28.6
# 6    wrn28-10  cifar100              17.4              17.40      26.6
# 7  resnext-29  cifar100              18.3              18.30      28.1
# 8   resnet-18  cifar100              21.6              21.60      29.9
# 9   resnet-20  cifar100               NaN              30.90       NaN
#
#    mce_repro  mfr_orig  mfr_repro  adv_error_orig  adv_error_repro  \
# 0      8.581       1.3       1.40            74.4            74.40
# ...
